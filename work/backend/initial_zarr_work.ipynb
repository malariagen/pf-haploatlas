# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import dask
import dask.array as da
from dask.diagnostics.progress import ProgressBar
import allel
# silence some warnings
dask.config.set(**{'array.slicing.split_large_chunks': False})
import malariagen_data

# %%
pf7 = malariagen_data.Pf7()
pf7_metadata = pf7.sample_metadata()
variant_dataset = pf7.variant_calls()
extended_variant_dataset = pf7.variant_calls(extended=True)

# %%
variant_dataset
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 10145661, alleles: 7, samples: 20864,
#                           ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
# ...

# %%
# qc_pass = (pf7_metadata["QC pass"] == True) & (pf7_metadata["% callable"] >= 80)

samples_of_interest = (variant_dataset.sample_id == "FP0008-C").compute()

data1 = variant_dataset.isel(samples = samples_of_interest)
# del pf7, qc_pass

# data2 = data1.where(data1.variant_filter_pass.compute(), other = False, drop = True)
# del data1

# data3 = data2.where(data2.variant_is_snp.compute(), other = False, drop = True)
# del data2

# data4 = data3.where(data3.variant_CDS.compute(), other = False, drop = True)
# del data3

# data5 = data4.where(data4.variant_numalt.compute() == 1, other = False, drop = True)
# del data4

# %%
data1
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 10145661, alleles: 7, samples: 1, ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(1,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
# ...

# %%
# sample_sequences[sample] = [ref_sequence.tomutable(), ref_sequence.tomutable()] # Causing an error - tomutable deprecated
# sample_offsets[sample] = [0, 0]
# PID[sample] = ''
# non_phased_het_seen[sample] = False
# sample_unphaseable[sample] = ''
# aa_haplotype[sample] = ''
# nucleotide_haplotype[sample] = ''
# num_missing[sample] = 0
# num_called[sample] = 0
# swap_phasing[sample] = False
# first_PGT[sample] = ''

# %%
extended_variant_dataset
# Out:
# <xarray.Dataset>
# Dimensions:                                        (variants: 10145661,
#                                                     alleles: 7, samples: 20864,
#                                                     ploidy: 2, genotypes: 3,
#                                                     sb_statistics: 4,
#                                                     alt_alleles: 6)
# Coordinates:
#     variant_position                               (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom                                  (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id                                      (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy, genotypes,
#                                 sb_statistics, alt_alleles
# Data variables: (12/92)
# ...

# %%
extended_variant_dataset.call_PID[:5].compute()
# Out:
# <xarray.DataArray 'call_PID' (variants: 5, samples: 20864)>
# array([['', '', '', ..., '', '', ''],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['', '', '', ..., '', '', ''],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.']], dtype=object)
# Coordinates:
#     variant_position  (variants) int32 30 37 51 58 60
#     variant_chrom     (variants) object 'Pf3D7_01_v3' ... 'Pf3D7_01_v3'
#     sample_id         (samples) object 'FP0008-C' 'FP0009-C' ... 'SPT43404'
# Dimensions without coordinates: variants, samples

# %%
extended_variant_dataset.call_PGT.compute()
